# %%
furniture = ["table", "chair", "shelf", "bed", "sofa"]
print (furniture[1] + " " + furniture[2])

for i in furniture:
    if i == "sofa":
        print (i)
# Out:
# chair shelf
# sofa

# %%
import random
x = 1
sum = 0
thrownDiceNumbers = []


while x < 6:
    thrownDiceNumbers.append(random.randint(1,6))
    x = x + 1

print (thrownDiceNumbers)

for i in thrownDiceNumbers:
    sum = sum + i
print ("Sum of the rolls is: " + str(sum))

iso = max(thrownDiceNumbers)
print (iso)
# Out:
# [2, 6, 1, 6, 3]
# Sum of the rolls is: 18
# 6
