# %%
answer = "John"
y = "y"
n = "n"

guesses = 0
def doContinue():
    if n == input("Do you want to quit? (y/n)"):
        guessing()
    else:
        exit

def guessing():
    global guesses
    guesses = guesses + 1
    guess = (input("Please guess my name"))
    if guess == answer:
        print("You win!")
        print("It took you " + str(guesses) + " tries.")
    else:
        doContinue()

guessing()
